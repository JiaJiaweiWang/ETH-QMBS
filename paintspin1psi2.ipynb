# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from qutip import *
from matplotlib.ticker import MultipleLocator

# %%
tlist=np.linspace(0,30,300)

# %%
evscE=qload('H_psi2')
evL1E=qload('L50_psi2')
evL2E=qload('L100_psi2')
evL3E=qload('L200_psi2')
evLa1E=qload('La50_psi2')
evLa2E=qload('La100_psi2')
evLa3E=qload('La200_psi2')

# %%
d=3
N=6
st1=basis(d,0)
st2=basis(d,1)
st3=basis(d,2)

psi2=tensor(st1,st1,st2,st2,st3,st1)

evsc=expect(psi2*psi2.dag(),evscE.states)
evL1=expect(psi2*psi2.dag(),evL1E.states)
evL2=expect(psi2*psi2.dag(),evL2E.states)
evL3=expect(psi2*psi2.dag(),evL3E.states)
evLa1=expect(psi2*psi2.dag(),evLa1E.states)
evLa2=expect(psi2*psi2.dag(),evLa2E.states)
evLa3=expect(psi2*psi2.dag(),evLa3E.states)

# %%
qsave(evsc,'spin1Hscarpsi2')
qsave(evL1,'spin1L50psi2')
qsave(evL2,'spin1L100psi2')
qsave(evL3,'spin1L200psi2')
qsave(evLa1,'spin1Lp50psi2')
qsave(evLa2,'spin1Lp100psi2')
qsave(evLa3,'spin1Lp200psi2')

# %%
x_major_locator = MultipleLocator(10)
y_major_locator = MultipleLocator(0.5)

fig, axes = plt.subplots(1,1)

axes.plot(tlist, evsc,linewidth=2, label=r'$H$',color='b')
axes.plot(tlist, evL1,linewidth=2, label=r'$\mathcal{L}_{+},c=50$',color='silver')
axes.plot(tlist, evL2,linewidth=2, label=r'$\mathcal{L}_{+},c=100$',color='dimgrey')
axes.plot(tlist, evL3,linewidth=2, label=r'$\mathcal{L}_{+},c=200$',color='black')
axes.plot(tlist, evLa1,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=50$',color='darkred')
axes.plot(tlist, evLa2,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=100$',color='red')
axes.plot(tlist, evLa3,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=200$',color='salmon')
#plt.xlim(12.55,12.75)
#plt.ylim(0.76,0.79)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
axes.xaxis.set_major_locator(x_major_locator)
axes.yaxis.set_major_locator(y_major_locator)
plt.xlabel('t',fontsize=20)
plt.ylabel(r'$|\langle \psi(0) | \rho(t) |\psi(0) \rangle|^2$',fontsize=20)
#axes.legend(loc=1)
#axes.legend(framealpha=0.5)
plt.rc('axes',linewidth=2)
plt.savefig('spin1psi2.svg')

# %%
x_major_locator = MultipleLocator(0.4)
y_major_locator = MultipleLocator(0.05)

fig, axes = plt.subplots(1,1)

axes.plot(tlist, evsc,linewidth=2, label=r'$H$',color='b')
axes.plot(tlist, evL1,linewidth=2, label=r'$\mathcal{L}_{+},c=50$',color='silver')
axes.plot(tlist, evL2,linewidth=2, label=r'$\mathcal{L}_{+},c=100$',color='dimgrey')
axes.plot(tlist, evL3,linewidth=2, label=r'$\mathcal{L}_{+},c=200$',color='black')
axes.plot(tlist, evLa1,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=50$',color='darkred')
axes.plot(tlist, evLa2,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=100$',color='red')
axes.plot(tlist, evLa3,linewidth=2, linestyle='-.', label=r'$\mathcal{L}^{’}_{+},c=200$',color='salmon')
plt.xlim(23.5,24.5)
plt.ylim(0,0.1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
axes.xaxis.set_major_locator(x_major_locator)
axes.yaxis.set_major_locator(y_major_locator)
plt.xlabel('t',fontsize=20)
plt.ylabel(r'$|\langle \psi(0) | \rho(t) |\psi(0) \rangle|^2$',fontsize=20)
axes.legend(loc=1)
axes.legend(framealpha=0.5)
axes.legend(prop={'size':15})
plt.rc('axes',linewidth=2)
plt.savefig('spin1psi2sub.svg')
